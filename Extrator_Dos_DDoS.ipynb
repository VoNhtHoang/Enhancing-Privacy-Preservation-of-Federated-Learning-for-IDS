# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
import sqlite3
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

def process_data(combined_df):
    # y = np.array(yi).reshape(-1, 1)
    y_raw = combined_df.iloc[:, -1].values
    y = np.array(y_raw).reshape(-1, 1)

    attack_types =['BenignTraffic', 'DDoS-ICMP_Flood', 'DDoS-PSHACK_Flood', 'DDoS-RSTFINFlood', 'DDoS-SYN_Flood', 
                   'DDoS-SynonymousIP_Flood', 'DDoS-TCP_Flood', 'DDoS-UDP_Flood', 'DoS-SYN_Flood', 'DoS-TCP_Flood', 'DoS-UDP_Flood']

    label_mapping = {}

    # Init
    encode = OneHotEncoder(sparse_output=False)

    # Mã hóa dữ liệu
    y_encoded = encode.fit_transform(y)

    # lấy list label
    labels = encode.categories_[0]

    ## mapping
    for label in labels:
        label_mapping[label]= -1
        for inx, type in enumerate(attack_types):
            if label == type:
                label_mapping[label] = inx
                break

    # print(label_mapping)

    for i, value in enumerate(combined_df['label']):
        combined_df.at[i, 'label'] = label_mapping.get(value, -1)
        
    # loại bỏ những hàng mà cột label chứa giá trị -1
    combined_df = combined_df[combined_df['label'] != -1]
    
    return combined_df

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob

folder_path ="./Dataset"
output_file="C:/Users/hoang/FileCSV_DACN_2025/Benign_ddos_dos_Mapped_Dataset.csv"
# Lấy danh sách tất cả các file CSV trong folder
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

# Đọc tất cả các file CSV vào danh sách DataFrame
# dfs = [pd.read_csv(file) for file in csv_files]
header_saved=False
for file in csv_files:
    print(f"Xử lý {file}")
    
    chunk_size = 1000000
    for chunk in pd.read_csv(file, chunksize=chunk_size):
        chunk = process_data(chunk)
        # Ghi vào file CSV đích (append mode)
        chunk.to_csv(output_file, mode="a", header=not header_saved, index=False)
        header_saved = True  # Chỉ ghi header lần đầu tiên
        
# # Nếu muốn gộp tất cả các file CSV thành một DataFrame duy nhất
# combined_df = pd.concat(dfs, ignore_index=True)
# Out:
# Xử lý ./Dataset\part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00066-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00067-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00068-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00069-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00070-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00071-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00072-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00073-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00074-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00075-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00076-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00077-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00078-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00079-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00080-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00081-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00082-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00083-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00084-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00085-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00086-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00087-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00088-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00089-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00090-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00091-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00092-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00093-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00094-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00095-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00096-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00097-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00098-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00099-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00101-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00102-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00103-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00104-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00105-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00106-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00107-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00108-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00109-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00110-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00111-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00112-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00114-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00115-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00116-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00117-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00118-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00119-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00120-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00122-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00123-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00124-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00125-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00126-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00127-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00128-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00129-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00130-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00131-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00132-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00133-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00134-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00135-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00136-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00137-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00138-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00139-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00140-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00141-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00142-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00143-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00144-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00145-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00146-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00147-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00148-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00149-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00150-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00151-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00152-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00153-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00154-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00155-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00156-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00157-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00158-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00159-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00160-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00161-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00162-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00163-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00164-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00165-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00166-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00167-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv
# Xử lý ./Dataset\part-00168-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv

# %% [markdown]
# # Chia Dataset Cho FL

# %%
import dask.dataframe as dd
from dask.distributed import Client
import numpy as np
import pandas as pd
import sys, os

# Khởi tạo Dask client để tối ưu hiệu suất
client = Client()

file_path = "C:/Users/hoang/FileCSV_DACN_2025/Benign_ddos_dos_Mapped_Dataset.csv"
output_files = ["_file1.csv", "_file2.csv", "_file3.csv"]
# Tỉ lệ chia (3:2:1)

# Cấu hình
chunksize = 100000  # Đọc từng phần (tuỳ vào RAM)
temp_dir = "C:/Users/hoang/FileCSV_DACN_2025/ddos_dos"  # Thư mục lưu file tạm

output_files = [temp_dir + output_file for output_file in output_files]
print(output_files)

header_saved=False
for chunk in pd.read_csv(file_path, chunksize=chunksize):
    df_1 = chunk.sample(frac=1/6, random_state=42)
    df_rest = chunk.drop(df_1.index)

    df_2 = df_rest.sample(frac=2/5, random_state=42)
    df_3 = df_rest.drop(df_2.index)

    df_1.to_csv(output_files[0], mode="a", header=not header_saved, index=False)
    df_2.to_csv(output_files[1], mode="a", header=not header_saved, index=False)
    df_3.to_csv(output_files[2], mode="a", header=not header_saved, index=False)
    header_saved = True
# Out:
# ['C:/Users/hoang/FileCSV_DACN_2025/ddos_dos_file1.csv', 'C:/Users/hoang/FileCSV_DACN_2025/ddos_dos_file2.csv', 'C:/Users/hoang/FileCSV_DACN_2025/ddos_dos_file3.csv']
